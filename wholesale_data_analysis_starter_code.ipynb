# %% [markdown]
# ## Part 1: Explore the Data
#
# Import the data and use Pandas to learn more about the dataset.

# %%
import pandas as pd

df = pd.read_csv('Resources/client_dataset.csv')
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year         item_id     category         subcategory  \
# ...

# %%
# View the column names in the data
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')

# %%
# Use the describe function to gather some basic statistics
df.describe() #returns the mean, std, min, quartiles, and max
# Out:
#           client_id      order_id    order_week    order_year    unit_price  \
# count  54639.000000  5.463900e+04  54639.000000  54639.000000  54639.000000
# mean   54837.869416  5.470190e+06     11.359139   2022.993064    136.267207
# std    25487.438231  2.599807e+06      7.023499      0.082997    183.873135
# min    10033.000000  1.000886e+06      1.000000   2022.000000      0.010000
# 25%    33593.000000  3.196372e+06      6.000000   2023.000000     20.800000
# 50%    53305.000000  5.496966e+06     11.000000   2023.000000     68.310000
# 75%    78498.000000  7.733869e+06     17.000000   2023.000000    173.160000
# max    99984.000000  9.998480e+06     52.000000   2023.000000   1396.230000
#
#           unit_cost   unit_weight           qty   line_number
# count  54639.000000  54639.000000  5.463900e+04  54639.000000
# mean      99.446073      5.004116  5.702646e+02      2.979667
# std      133.164267      5.326599  1.879552e+04      2.436320
# ...

# %%
# Use this space to do any additional research
# and familiarize yourself with the data.
var0 = df.index
print(var0)

var1 = df.columns
print(var1)

var2 = df.count()
print(var2)

var3 = df.sort_values(by='category')
print(f"this is the sroted values, {var3}")

# type = type(df)
# print(f"this the type,{type}")
# Out:
# RangeIndex(start=0, stop=54639, step=1)
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number'],
#       dtype='object')
# first          54639
# last           54639
# job            54639
# phone          54639
# email          54639
# client_id      54639
# order_id       54639
# order_date     54639
# order_week     54639
# order_year     54639
# item_id        54639
# category       54639
# subcategory    54639
# unit_price     54639
# unit_cost      54639
# unit_weight    54639
# qty            54639
# line_number    54639
# dtype: int64
# this is the sroted values,           first       last                       job                 phone  \
# 47373      Mark   Thompson  Journalist, broadcasting     529-839-1559x9494
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54639 entries, 0 to 54638
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   first        54639 non-null  object
#  1   last         54639 non-null  object
#  2   job          54639 non-null  object
#  3   phone        54639 non-null  object
#  4   email        54639 non-null  object
#  5   client_id    54639 non-null  int64
#  6   order_id     54639 non-null  int64
#  7   order_date   54639 non-null  object
#  8   order_week   54639 non-null  int64
#  9   order_year   54639 non-null  int64
#  10  item_id      54639 non-null  object
#  11  category     54639 non-null  object
#  12  subcategory  54639 non-null  object
#  13  unit_price   54639 non-null  float64
#  14  unit_cost    54639 non-null  float64
#  15  unit_weight  54639 non-null  float64
#  16  qty          54639 non-null  int64
#  17  line_number  54639 non-null  int64
# ...

# %%
# What three item categories had the most entries?
#value_counts returns the about of time this value repeats
df['category'].value_counts().head(3)
# Out:
# category
# consumables    23538
# furniture      11915
# software        8400
# Name: count, dtype: int64

# %%
# For the category with the most entries, which subcategory had the most entries?
df.loc[df['category']=='consumables','subcategory'].value_counts().head(1)
# Out:
# subcategory
# bathroom supplies    6424
# Name: count, dtype: int64

# %%
# Testing for comprehenion 
df.loc[df['category']=='consumables']
# Out:
#            first       last                                      job  \
# 1        Tiffany      Myers                          Music therapist
# 3         Nathan      Baker                    Accounting technician
# 4      Christina   Schwartz                             Chiropractor
# 6          Brian      Moore                                  Barista
# 7          Jesus     Wright                       Theme park manager
# ...          ...        ...                                      ...
# 54629      Linda  Henderson  Scientist, research (physical sciences)
# 54632     Austin     Fuller                       Investment analyst
# 54633     Tamara      Jones                        Fish farm manager
# 54635    Derrick      Moore                                 Musician
# 54636     Monica  Gutierrez                         Graphic designer
#
#                      phone                                email  client_id  \
# ...

# %%
# Which five clients had the most entries in the data?
df['client_id'].value_counts().head(5)
# Out:
# client_id
# 33615    220
# 66037    211
# 46820    209
# 38378    207
# 24741    207
# Name: count, dtype: int64

# %%
# Store the client ids of those top 5 clients in a list.
client_list = list(df['client_id'].value_counts().head(5).index)
client_list
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How many total units (the qty column) did the client with the most entries order order?
df.loc[df['client_id']==33615,'qty'].sum()
# (df['client_id']).dtypes
# Out:
# 64313

# %% [markdown]
# ## Part 2: Transform the Data
# Do we know that this client spent the more money than client 66037? If not, how would we find out? Transform the data using the steps below to prepare it for analysis.

# %%
# Create a column that calculates the subtotal for each line using the unit_price and the qty
df['line_subtotal'] = df['unit_price'] * df['qty']
# df[['client_id', 'unit_price', 'qty', 'line_subtotal']]
df
# Out:
#            first       last                      job               phone  \
# 0         Donald    Harding             Immunologist  793-904-7725x39308
# 1        Tiffany      Myers          Music therapist    201.442.4543x942
# 2        Shannon     Watson             Immunologist   687.737.9424x8503
# 3         Nathan      Baker    Accounting technician    827-788-8123x012
# 4      Christina   Schwartz             Chiropractor        265-829-3643
# ...          ...        ...                      ...                 ...
# 54634     Lauren      Reese           Radio producer  977.877.5272x11382
# 54635    Derrick      Moore                 Musician        358.661.5483
# 54636     Monica  Gutierrez         Graphic designer    294.805.9100x339
# 54637      Wanda    Solomon             Toxicologist       (311)767-4924
# 54638     Dwayne       Bell  Chief Financial Officer   606-619-7667x9508
#
#                                      email  client_id  order_id  order_date  \
# ...

# %%
df.columns
# Out:
# Index(['first', 'last', 'job', 'phone', 'email', 'client_id', 'order_id',
#        'order_date', 'order_week', 'order_year', 'item_id', 'category',
#        'subcategory', 'unit_price', 'unit_cost', 'unit_weight', 'qty',
#        'line_number', 'line_subtotal'],
#       dtype='object')

# %%
# Create a column for shipping price.
# Assume a shipping price of $7 per pound for orders over 50 pounds and $10 per pound for items 50 pounds or under.
# Received peer's support to solve problem 

df['total_weight'] = df['unit_weight'] * df['qty']

def rate_price(total_weight):
    return 7 if total_weight>50 else 10
    
df['shipping_price'] = df['total_weight'].apply(rate_price) * df['total_weight']
#print results
df[['unit_price','unit_weight', 'qty', 'total_weight', 'shipping_price']].head(3)
# Out:
#    unit_price  unit_weight  qty  total_weight  shipping_price
# 0     1096.80         7.50  105        787.50         5512.50
# 1       24.95         1.49   21         31.29          312.90
# 2       13.52         1.68   39         65.52          458.64

# %%
# Create a column for the total price using the subtotal and the shipping price along with a sales tax of 9.25%

df['total_price'] = ((df['shipping_price'] + df['line_subtotal']) * 1.0925).round(2)
#print results
df[['total_price']]
# Out:
#        total_price
# 0        131839.08
# 1           914.26
# 2          1077.12
# 3          1543.57
# 4         11364.40
# ...            ...
# 54634      3564.87
# 54635     14813.24
# 54636     49184.90
# 54637     15632.71
# 54638     19711.43
#
# [54639 rows x 1 columns]

# %%
# Create a column for the cost of each line using unit cost, qty, and
# shipping price (assume the shipping cost is exactly what is charged to the client).
df['line_cost'] = (df['unit_cost'] * df['qty']) + df['shipping_price']
#printing the results for multiple columns
df[['line_cost', 'unit_cost', 'qty', 'shipping_price']]
# Out:
#        line_cost  unit_cost   qty  shipping_price
# 0       85597.05     762.71   105         5512.50
# 1         629.79      15.09    21          312.90
# 2         765.18       7.86    39          458.64
# 3        1077.35      24.85    29          356.70
# 4        8663.60     108.17    20         6500.20
# ...          ...        ...   ...             ...
# 54634    2222.55      51.60    33          519.75
# 54635   12095.92     175.46    47         3849.30
# 54636   41054.25      57.31   475        13832.00
# 54637   14280.00       1.22   112        14143.36
# 54638   16599.10       1.61  1031        14939.19
#
# [54639 rows x 4 columns]

# %%
# Create a column for the profit of each line using line cost and line price

df['profit'] =  df['total_price'] - df['line_cost']
# Results
df[['order_id','line_cost', 'total_price', 'unit_cost', 'qty', 'shipping_price','profit']]
# Out:
#        order_id  line_cost  total_price  unit_cost   qty  shipping_price  \
# 0       8953482   85597.05    131839.08     762.71   105         5512.50
# 1       8069089     629.79       914.26      15.09    21          312.90
# 2       1902144     765.18      1077.12       7.86    39          458.64
# 3       9031802    1077.35      1543.57      24.85    29          356.70
# 4       1322274    8663.60     11364.40     108.17    20         6500.20
# ...         ...        ...          ...        ...   ...             ...
# 54634   9021716    2222.55      3564.87      51.60    33          519.75
# 54635   6290153   12095.92     14813.24     175.46    47         3849.30
# 54636   8692622   41054.25     49184.90      57.31   475        13832.00
# 54637   7592730   14280.00     15632.71       1.22   112        14143.36
# 54638   7489403   16599.10     19711.43       1.61  1031        14939.19
#
#          profit
# 0      46242.03
# 1        284.47
# 2        311.94
# 3        466.22
# ...

# %% [markdown]
# ## Part 3: Confirm your work
# You have email receipts showing that the total prices for 3 orders. Confirm that your calculations match the receipts. Remember, each order has multiple lines.
#
# Order ID 2742071 had a total price of \$152,811.89
#
# Order ID 2173913 had a total price of \$162,388.71
#
# Order ID 6128929 had a total price of \$923,441.25

# %%
df.loc[df['order_id'] == 2742071, 'total_price'].sum().round(2)
# Out:
# 152811.89

# %%
# Check your work using the totals above
    
select_order = [2742071, 2173913, 6128929]
# result_list = []

for i in select_order:
    result= df.loc[df['order_id'] == i, 'total_price'].sum().round(2)
    # result_list.append(result)
    # print(result_list)
    print(f"Order ID = {i}, Result {result}")
# Out:
# Order ID = 2742071, Result 152811.89
# Order ID = 2173913, Result 162388.71
# Order ID = 6128929, Result 923441.25

# %% [markdown]
# ## Part 4: Summarize and Analyze
# Use the new columns with confirmed values to find the following information.

# %%
df.head()
# Out:
#        first      last                    job               phone  \
# 0     Donald   Harding           Immunologist  793-904-7725x39308
# 1    Tiffany     Myers        Music therapist    201.442.4543x942
# 2    Shannon    Watson           Immunologist   687.737.9424x8503
# 3     Nathan     Baker  Accounting technician    827-788-8123x012
# 4  Christina  Schwartz           Chiropractor        265-829-3643
#
#                                  email  client_id  order_id  order_date  \
# 0     harding.donald.7185@sullivan.com      58515   8953482  2023-04-28
# 1    myers.t.6537@ferguson-johnson.net      37609   8069089  2023-05-19
# 2                swatson8146@payne.net      57113   1902144  2023-01-29
# 3               bakernathan@benson.com      46554   9031802  2023-04-25
# 4  christinaschwartz9252@mcconnell.com      92089   1322274  2023-05-28
#
#    order_week  order_year  ... unit_cost unit_weight  qty  line_number  \
# ...

# %%
client_list
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# How much did each of the top 5 clients by quantity spend? Check your work from Part 1 for client ids.

# using the quantity spend metric return the top 5 clients. 
# columns= ['qty', 'shipping_price', 'total_price', 'line_cost', 'line_profit']

def client_totals(client_id, column):
    client_df = df.loc[df['client_id'] == client_id, column].sort_values(ascending =False)
    return round(client_df.sum(), 2)

for client_id in client_list:
    print(f"{client_id}: ${client_totals(client_id, 'total_price')}")
# Out:
# 33615: $8377308.52
# 66037: $10259514.79
# 46820: $9743794.36
# 38378: $12906550.87
# 24741: $82268892.02

# %%
client_list
# Out:
# [33615, 66037, 46820, 38378, 24741]

# %%
# Create a summary DataFrame showing the totals for the for the top 5 clients with the following information:
# total units purchased, total shipping price, total revenue, and total profit. 
df_summary = df[['client_id','shipping_price', 'total_price', 'line_cost', 'profit', 'qty']]

# for id in client_list:
df_summary = df_summary.loc[df_summary['client_id'].isin(client_list)]


df_summary = df_summary.groupby(['client_id']).sum().reset_index()
df_summary
# Out:
#    client_id  shipping_price  total_price    line_cost       profit     qty
# 0      24741      5126448.37  82268892.02  45688899.71  36579992.31  239862
# 1      33615      1828984.89   8377308.52   6175313.91   2201994.61   64313
# 2      38378      3429455.40  12906550.87   9634720.98   3271829.89   73667
# 3      46820      1601448.84   9743794.36   7007191.64   2736602.72   75768
# 4      66037      1395151.85  10259514.79   7004482.98   3255031.81   43018

# %%
# Format the data and rename the columns to names suitable for presentation.

# Define the money columns. 


# Define a function that converts a dollar amount to millions.


# Apply the currency_format_millions function to only the money columns. 
# Found a different solution not using functions. 

df_summary[['shipping_price','total_price','line_cost','profit']]/=1000000
df_summary

# Rename the columns to reflect the change in the money format. 
df_summary = df_summary.rename(columns={"shipping_price":"shipping_price_millions",
"total_price":"total_price_millions",
"line_cost": "line_cost_millions",
"profit": "profits_millions"})

df_summary
# Out:
#    client_id  shipping_price_millions  total_price_millions  \
# 0      24741                 5.126448             82.268892
# 1      33615                 1.828985              8.377309
# 2      38378                 3.429455             12.906551
# 3      46820                 1.601449              9.743794
# 4      66037                 1.395152             10.259515
#
#    line_cost_millions  profits_millions     qty
# 0           45.688900         36.579992  239862
# 1            6.175314          2.201995   64313
# 2            9.634721          3.271830   73667
# 3            7.007192          2.736603   75768
# 4            7.004483          3.255032   43018

# %%
# Sort the updated data by "Total Profit (millions)" form highest to lowest and assign the sort to a new DatFrame.
df_summary_sort = df_summary.sort_values('profits_millions',ascending=False)
df_summary_sort
# Out:
#    client_id  shipping_price_millions  total_price_millions  \
# 0      24741                 5.126448             82.268892
# 2      38378                 3.429455             12.906551
# 4      66037                 1.395152             10.259515
# 3      46820                 1.601449              9.743794
# 1      33615                 1.828985              8.377309
#
#    line_cost_millions  profits_millions     qty
# 0           45.688900         36.579992  239862
# 2            9.634721          3.271830   73667
# 4            7.004483          3.255032   43018
# 3            7.007192          2.736603   75768
# 1            6.175314          2.201995   64313
